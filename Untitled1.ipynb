# %%
import pandas as pd
import Procedatos as P
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
data = P.leer_datos([1],[12],[100],[100],
                        verb=False,muchos=False,cola=False)

# %%
data.head()
# Out:
#    Memoria  Num_predic  Num_agentes  Num_rondas  Identificador  Ronda  Agente  \
# 0        1          12          100         100            400      0       0
# 1        1          12          100         100            400      1       0
# 2        1          12          100         100            400      2       0
# 3        1          12          100         100            400      3       0
# 4        1          12          100         100            400      4       0
#
#    Estado  Puntaje          Politica  Prediccion  Precision
# 0       1        1         1-ventana          54        NaN
# 1       1       -1         1-ciclico         100       46.0
# 2       0        0  1-ciclico-espejo         100        0.0
# 3       0        0         1-ciclico           0        0.0
# 4       1       -1  1-ciclico-espejo           0        0.0

# %%
df = data.groupby(['Identificador','Ronda'])['Estado'].mean().reset_index()
sns.lineplot(x='Ronda',y='Estado',hue='Identificador',data=df)
# Out:
# <AxesSubplot:xlabel='Ronda', ylabel='Estado'>

# %%
ide = data.Identificador.unique().tolist()[0]
ronda = 1
df_id = data[(data['Identificador'] == ide) & (data['Ronda'] == ronda)]
df_id.Politica.unique().tolist()
# Out:
# ['1-ciclico-espejo']

# %%
sns.histplot(df_id.Prediccion)
# Out:
# <AxesSubplot:xlabel='Prediccion', ylabel='Count'>

# %%
df_id.Estado.mean()
# Out:
# 1.0

# %%
sns.histplot(df_id.Precision)
# Out:
# <AxesSubplot:xlabel='Precision', ylabel='Count'>
