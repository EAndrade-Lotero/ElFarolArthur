# %%
import pandas as pd
import Procedatos as P
import Graficos as G
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Variando memoria con 1000 agentes

# %%
data = P.leer_datos([1,3,6,9,12],[1],[0],verb=False,muchos=True,cola=True)
data['Modelo'] = data['Memoria']
G.comparacion(data)

# %% [markdown]
# Variando memoria con 100 agentes

# %%
data = P.leer_datos([1,3,6,9,12],[1],[0],verb=False,muchos=False)
data['Modelo'] = data['Memoria']
G.comparacion(data)

# %% [markdown]
# Variando predictores con 1000 agentes

# %%
data = P.leer_datos([12],[1,3,6,9,12],[0],verb=False,muchos=True)
data['Modelo'] = data['Num_predic']
G.comparacion(data)

# %% [markdown]
# Variando predictores con 100 agentes

# %%
data = P.leer_datos([12],[1,3,6,9,12],[0],verb=False,muchos=False)
data['Modelo'] = data['Num_predic']
G.comparacion(data)

# %% [markdown]
# Heatmaps

# %%
data = P.leer_datos([1,3,6,9,12],[1,3,6,9,12],[0],verb=False,muchos=True,cola=True)
variables = ['Attendance','Deviation', 'Efficiency','Gap','Gini', 'Iniquity']
# variables = ['Deviation']
G.graficar_heatmaps(data, parametros=['Memoria','Num_predic'], variables=variables)
# Out:
# Solo últimas 20 rondas!
# Attendance y Deviation listos!
# /Users/edgar/Repositorios/ElFarolArthur/Procedatos.py:273: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['lleva_recurso'] = df['Puntaje'].apply(lambda x: 1 if x == 1 else 0)
# Dataframe listo!

# %%
data = P.leer_datos([1,3,6,9,12],[1,3,6,9,12],[0],verb=False,muchos=False,cola=True)
variables = ['Attendance','Deviation', 'Efficiency','Gap','Gini', 'Iniquity']
# variables = ['Deviation']
G.graficar_heatmaps(data, parametros=['Memoria','Num_predic'], variables=variables)
# Out:
# Solo últimas 20 rondas!
# Attendance y Deviation listos!
# /Users/edgar/Repositorios/ElFarolArthur/Procedatos.py:273: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['lleva_recurso'] = df['Puntaje'].apply(lambda x: 1 if x == 1 else 0)
# Dataframe listo!
