# %%
import pandas as pd
import Procedatos as P
import Graficos as G
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Figura 1

# %%
data = P.leer_datos([1,3,6,9,12],[1,3,6,9,12],[0],[100],[100],
                    verb=False,muchos=False,cola=True)

# %%
variables = ['Attendance','Deviation','Precision','Efficiency','Gini','TBFI']
G.graficar_heatmaps(data, parametros=['Memoria','Num_predic'], 
                    variables=variables,to_file=True)
# Out:
# Attendance y Deviation listos!
# Dataframe listo!
# Imagen guardada!
