# %%
import pandas as pd
import Procedatos as P
import Graficos as G
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
data = P.leer_datos([12],[12],[0],[100],[100,1000,2000],verb=False,muchos=False)
data['Modelo'] = data['Num_rondas']

# %%
data.head()
# Out:
#    Memoria  Num_predic  Conectividad  Num_agentes  Num_rondas  Identificador  \
# 0       12          12           0.0          100         100              0
# 1       12          12           0.0          100         100              0
# 2       12          12           0.0          100         100              0
# 3       12          12           0.0          100         100              0
# 4       12          12           0.0          100         100              0
#
#    Ronda  Agente  Estado  Puntaje               Politica  Prediccion  \
# 0      0       0       0        0          7-ventana(80)          50
# 1      1       0       1       -1          2-ventana(87)          75
# 2      2       0       0        0  11-ventana-espejo(47)          37
# 3      3       0       1       -1          2-ventana(87)          70
# 4      4       0       0        0  11-ventana-espejo(47)          42
#
#    Precision  Modelo
# 0        NaN     100
# 1     50.000     100
# ...

# %%
G.comparacion(data)

# %%
sns.lineplot(x='Ronda',
             y='Estado',
             hue='Modelo',
             data=data.groupby(['Modelo','Identificador','Ronda'])['Estado'].mean().reset_index())
# Out:
# <AxesSubplot:xlabel='Ronda', ylabel='Estado'>
