# %%
import pandas as pd
import Procedatos as P
import Graficos as G
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
data = P.leer_datos([12],[12],[0],[100],[100,1000,2000],
                    verb=False,
                    cola=True,
                    muchos=False)
data['Modelo'] = data['Num_rondas']

# %%
G.comparacion(data)
